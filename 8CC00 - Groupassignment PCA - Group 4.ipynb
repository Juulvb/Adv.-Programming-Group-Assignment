# %% [markdown]
# # Groupassignment PCA

# %% [markdown]
# J.P.A. (Juul) van Boxtel - 1019575
# B.W.M. (Bram) Geven - 1327909
# M.A. (Mirthe) Kamphuis - 1259725
# K.J.M. (Kirsten) Lukassen - 1228126
#
# This is the Jupyter Notebook for the groupassignment of the course 8CC00 made by group 4. This notebook guides the reader through all different methods that were created for this groupassignment. The documentation is mainly in the code and will therefore not be repeated in the text of the notebook, only additional information and a discussion of the results are given.
#
# To provide a shorter and clearer way to the results, a [seperate report](../8CC00-GroupassignmentPCA-Group04.pdf) has been written. Next to the results, the rebuttals to the evaluations of the other groupmembers are provided in this separate report.
#
# The full code, including all modules and methods, can be found in the zip file.

# %% [markdown]
# ### Explanation datasets

# %% [markdown]
# ### Methods
